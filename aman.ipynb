# %%
# !pip install pycaret[full]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.2/320.2 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 25.6 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 282.6/282.6 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.1/167.1 kB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.8/137.8 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 36.1 MB/s eta 0:00:00:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 458.9/458.9 kB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.7/147.7 kB 7.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 42.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 35.0 MB/s eta 0:00:00:00:01
# ...

# %%
pip install pycaret
# Out:
# ...
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# ...
#   Using cached pyod-1.0.7.tar.gz (147 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached wordcloud-1.8.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (458 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 36.4 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached ipywidgets-8.0.4-py3-none-any.whl (137 kB)
# ...
#   Using cached lightgbm-3.3.3-py3-none-manylinux1_x86_64.whl (2.0 MB)
# ...
#   Using cached kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached mlxtend-0.21.0-py2.py3-none-any.whl (1.3 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 58.9 MB/s eta 0:00:00:00:0100:01
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [3837 lines of output]
# ...

# %%
pip uninstall PyYAML
# Out:
# WARNING: Skipping PyYAML as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install PyYAML==5.4.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 4.1 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for PyYAML: filename=PyYAML-5.4.1-cp310-cp310-linux_x86_64.whl size=568850 sha256=6c5a4b4096c352959624aad0ae004b2ecaed6e1776063a769219fe943357ea25
#   Stored in directory: /home/codespace/.cache/pip/wheels/10/3f/c1/6feec52270653969575b83de934b04be56d7a9e961be5041ea
# Successfully built PyYAML
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error 
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
df = pd.read_csv('FRCM.csv')
df.head()
# Out:
#    n  bcs   fck  tf   bf   Lb    ff     Ef    Pu
# 0  1  100  30.0  10  100   50  5213  271.0  5.82
# 1  1  100  30.0  10  100   50  5213  271.0  5.19
# 2  1  100  30.0  10  100  100  5213  271.0  7.64
# 3  1  100  30.0  10  100  150  5213  271.0  9.01
# 4  1  100  30.0  10  100  150  5213  271.0  8.97

# %%
round(df.describe(),1)
# Out:
#            n    bcs    fck     tf     bf     Lb      ff     Ef     Pu
# count  336.0  336.0  336.0  336.0  336.0  336.0   336.0  336.0  336.0
# mean     1.4  120.5   35.6    8.9   70.8  237.3  3666.9  214.5   11.3
# std      0.8   17.0    9.8    2.2   23.2  110.9  1611.3   65.1    9.9
# min      1.0  100.0   14.7    4.0   34.0   50.0   767.0   56.0    0.8
# 25%      1.0  100.0   30.3    8.0   50.0  150.0  3014.0  206.0    5.1
# 50%      1.0  125.0   33.5   10.0   60.0  200.0  3800.0  225.0    7.1
# 75%      2.0  125.0   42.5   10.0   90.0  330.0  5213.0  270.0   12.9
# max      4.0  150.0   59.3   13.0  150.0  450.0  5800.0  278.0   41.9

# %%
df.shape
# Out:
# (336, 9)

# %%
x = "Pu"
sns.set_context("talk")
sns.jointplot(data = df, y="n", x=x, marginal_kws=dict(bins=20, fill=True),marginal_ticks=False, height = 5, ratio=2, s=100, alpha=0.8)
sns.jointplot(data = df, y="bcs", x=x, marginal_kws=dict(bins=20, fill=True),marginal_ticks=True, height = 5, ratio=2, s=100, alpha=0.8)
sns.jointplot(data = df, y="fck", x=x, marginal_kws=dict(bins=20, fill=True),marginal_ticks=True, height = 5, ratio=2, s=100, alpha=0.8)
sns.jointplot(data = df, y="tf", x=x, marginal_kws=dict(bins=20, fill=True),marginal_ticks=True, height = 5, ratio=2, s=100, alpha=0.8)
sns.jointplot(data = df, y="bf", x=x, marginal_kws=dict(bins=20, fill=True),marginal_ticks=True, height = 5, ratio=2, s=100, alpha=0.8)
sns.jointplot(data = df, y="Lb", x=x, marginal_kws=dict(bins=20, fill=True),marginal_ticks=True, height = 5, ratio=2, s=100, alpha=0.8)
sns.jointplot(data = df, y="ff", x=x, marginal_kws=dict(bins=20, fill=True),marginal_ticks=True, height = 5, ratio=2, s=100, alpha=0.8)
sns.jointplot(data = df, y="Ef", x=x, marginal_kws=dict(bins=20, fill=True),marginal_ticks=True, height = 5, ratio=2, s=100, alpha=0.8)

# %%
round(df.corr( ),2)
# Out:
#         n   bcs   fck    tf    bf    Lb    ff    Ef    Pu
# n    1.00 -0.43 -0.16 -0.42  0.03 -0.20  0.00  0.09  0.69
# bcs -0.43  1.00  0.37  0.08 -0.48 -0.01  0.01 -0.09 -0.22
# fck -0.16  0.37  1.00 -0.05 -0.18  0.03  0.63  0.68 -0.01
# tf  -0.42  0.08 -0.05  1.00  0.23  0.07 -0.24 -0.07 -0.30
# bf   0.03 -0.48 -0.18  0.23  1.00 -0.30 -0.25 -0.15  0.33
# Lb  -0.20 -0.01  0.03  0.07 -0.30  1.00  0.24  0.16 -0.31
# ff   0.00  0.01  0.63 -0.24 -0.25  0.24  1.00  0.82 -0.11
# Ef   0.09 -0.09  0.68 -0.07 -0.15  0.16  0.82  1.00  0.08
# Pu   0.69 -0.22 -0.01 -0.30  0.33 -0.31 -0.11  0.08  1.00

# %%
df_corr = round(df.corr( ),2)
plt.figure(figsize=(15,10))
sns.set(font_scale=1.4)
sns.heatmap(df_corr,annot=True,cmap=plt.cm.Greens)
# Out:
# <AxesSubplot: >

# %%
pip install pycaret
# Out:
# ...
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# ...
#   Using cached gensim-3.8.3.tar.gz (23.4 MB)
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached lightgbm-3.3.3-py3-none-manylinux1_x86_64.whl (2.0 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 36.4 MB/s eta 0:00:0000:0100:01m
# ...
#   Using cached imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# ...
#   Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# ...
#   Using cached cufflinks-0.17.3.tar.gz (81 kB)
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 328.5/328.5 kB 13.0 MB/s eta 0:00:00
# ...
#   Using cached Boruta-0.3-py3-none-any.whl (56 kB)
# ...
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
# ...

# %%
pip install pylance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 25.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 27.9 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pycaret[full]
# Out:
# ...
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# ...
#   Using cached yellowbrick-1.5-py3-none-any.whl (282 kB)
# ...
#   Using cached scipy-1.5.4.tar.gz (25.2 MB)
#   Installing build dependencies ... \

# %%
pip install pycaret
# Out:
# ...
#   Using cached pycaret-2.3.10-py3-none-any.whl (320 kB)
# ...
#   Using cached Boruta-0.3-py3-none-any.whl (56 kB)
# ...
#   Using cached kmodes-0.12.2-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached pyod-1.0.7.tar.gz (147 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached imbalanced_learn-0.7.0-py3-none-any.whl (167 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 31.5 MB/s eta 0:00:0000:01
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached scikit-learn-0.23.2.tar.gz (7.2 MB)
#   Installing build dependencies ... error
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [3831 lines of output]
#       Ignoring numpy: markers 'python_version == "3.6" and platform_system != "AIX" and platform_python_implementation == "CPython"' don't match your environment
# ...

# %%
from pycaret.regression import*
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pycaret.regression import*
#
# ModuleNotFoundError: No module named 'pycaret'
